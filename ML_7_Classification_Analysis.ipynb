# %%
import pandas as pd 
import numpy as np 
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\Utsav\Downloads\HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project
# 0                    0.38             0.53               2  \
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left
# 0                       157                   3              0     1  \
# 1                       262                   6              0     1
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.drop(['Department','salary'],axis="columns").groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project
# left
# 0               0.666810         0.715473        3.786664  \
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident
# left
# 0               199.060203            3.380032       0.175009  \
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
import seaborn as sns

# %%
count_df = df.groupby(['salary', 'left']).size().reset_index(name='count')

sns.set(style="whitegrid")
g = sns.catplot(x='salary', y='count', hue='left', data=count_df, kind='bar')

g.set_axis_labels('Salary', 'Number of People')
g.set(title='Number of People Left vs. Not Left by Salary')

# Show the plot
plt.show()

# %%
count_df
# Out:
#    salary  left  count
# 0    high     0   1155
# 1    high     1     82
# 2     low     0   5144
# 3     low     1   2172
# 4  medium     0   5129
# 5  medium     1   1317

# %%
pd.crosstab(df.salary,df.left).plot(kind="bar")
# Out:
#        satisfaction_level  last_evaluation  number_project
# 0                    0.38             0.53               2  \
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left
# 0                       157                   3              0     1  \
# 1                       262                   6              0     1
# ...
