# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Utsav\Desktop\Customer.csv")

# %%
df.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder

# %%
oe=OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])
le=LabelEncoder()

# %%
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,2:4],df.purchased)

# %%
x_train
# Out:
#      review education
# 11     Good        UG
# 8   Average        UG
# 33     Good        PG
# 26     Poor        PG
# 49     Good        UG
# 9      Good        UG
# 48     Good        UG
# 18     Good    School
# 5   Average    School
# 46     Poor        PG
# 20  Average    School
# 14     Poor        PG
# 1      Poor        UG
# 22     Poor        PG
# 45     Poor        PG
# 13  Average    School
# 40     Good    School
# 29  Average        UG
# 21  Average        PG
# 43     Poor        PG
# 39     Poor        PG
# 37  Average        PG
# 12     Poor    School
# 34  Average    School
# 30  Average        UG
# 0   Average    School
# 41     Good        PG
# 16     Poor        UG
# 15     Poor        UG
# 10     Good        UG
# 36     Good        UG
# 28     Poor    School
# 31     Poor    School
# 25     Good    School
# 47     Good        PG
# 17     Poor        UG
# 7      Poor    School

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
x_train
# Out:
#      review education
# 11     Good        UG
# 8   Average        UG
# 33     Good        PG
# 26     Poor        PG
# 49     Good        UG
# 9      Good        UG
# 48     Good        UG
# 18     Good    School
# 5   Average    School
# 46     Poor        PG
# 20  Average    School
# 14     Poor        PG
# 1      Poor        UG
# 22     Poor        PG
# 45     Poor        PG
# 13  Average    School
# 40     Good    School
# 29  Average        UG
# 21  Average        PG
# 43     Poor        PG
# 39     Poor        PG
# 37  Average        PG
# 12     Poor    School
# 34  Average    School
# 30  Average        UG
# 0   Average    School
# 41     Good        PG
# 16     Poor        UG
# 15     Poor        UG
# 10     Good        UG
# 36     Good        UG
# 28     Poor    School
# 31     Poor    School
# 25     Good    School
# 47     Good        PG
# 17     Poor        UG
# 7      Poor    School

# %%
x_train=oe.transform(x_train)
x_test=oe.transform(x_test)

# %%
x_train
# Out:
# array([[2., 1.],
#        [1., 1.],
#        [2., 2.],
#        [0., 2.],
#        [2., 1.],
#        [2., 1.],
#        [2., 1.],
#        [2., 0.],
#        [1., 0.],
#        [0., 2.],
#        [1., 0.],
#        [0., 2.],
#        [0., 1.],
#        [0., 2.],
#        [0., 2.],
#        [1., 0.],
#        [2., 0.],
#        [1., 1.],
#        [1., 2.],
#        [0., 2.],
#        [0., 2.],
#        [1., 2.],
#        [0., 0.],
#        [1., 0.],
#        [1., 1.],
#        [1., 0.],
#        [2., 2.],
#        [0., 1.],
#        [0., 1.],
#        [2., 1.],
#        [2., 1.],
#        [0., 0.],
#        [0., 0.],
#        [2., 0.],
#        [2., 2.],
#        [0., 1.],
#        [0., 0.]])

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
y_test=le.transform(y_test)
y_train=le.transform(y_train)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
x_train=pd.DataFrame(x_train,columns=['Review','Education'])
x_test=pd.DataFrame(x_test,columns=['Review','Education'])

# %%
x_train
# Out:
#     Review  Education
# 0      2.0        1.0
# 1      1.0        1.0
# 2      2.0        2.0
# 3      0.0        2.0
# 4      2.0        1.0
# 5      2.0        1.0
# 6      2.0        1.0
# 7      2.0        0.0
# 8      1.0        0.0
# 9      0.0        2.0
# 10     1.0        0.0
# 11     0.0        2.0
# 12     0.0        1.0
# 13     0.0        2.0
# 14     0.0        2.0
# 15     1.0        0.0
# 16     2.0        0.0
# 17     1.0        1.0
# 18     1.0        2.0
# 19     0.0        2.0
# 20     0.0        2.0
# 21     1.0        2.0
# 22     0.0        0.0
# 23     1.0        0.0
# 24     1.0        1.0
# 25     1.0        0.0
# 26     2.0        2.0
# 27     0.0        1.0
# 28     0.0        1.0
# 29     2.0        1.0
# 30     2.0        1.0
# 31     0.0        0.0
# 32     0.0        0.0
# 33     2.0        0.0
# 34     2.0        2.0
# 35     0.0        1.0
# 36     0.0        0.0

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.5384615384615384

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,model.predict(x_test))

# %%
cm
# Out:
# array([[3, 5],
#        [1, 4]], dtype=int64)

# %%
df.iloc[2]
# Out:
# age              70
# gender       Female
# review         Good
# education        PG
# purchased        No
# Name: 2, dtype: object

# %%
x_train.iloc[2]
# Out:
# Review       2.0
# Education    2.0
# Name: 2, dtype: float64
