# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('titanic.csv')[['Age','Pclass','SibSp','Parch','Survived']]

# %%
df.head()
# Out:
#     Age  Pclass  SibSp  Parch  Survived
# 0  22.0       3      1      0         0
# 1  38.0       1      1      0         1
# 2  26.0       3      0      0         1
# 3  35.0       1      1      0         1
# 4  35.0       3      0      0         0

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
df.dropna(inplace=True)

# %%
np.mean(cross_val_score(LogisticRegression(),df.iloc[:,0:4],df.iloc[:,4],scoring='accuracy',cv=20))
# Out:
# 0.6933333333333332

# %% [markdown]
# Applying Feature Construction

# %%
df['Family_Size']=df['SibSp']+df['Parch']+1

# %%
df
# Out:
#       Age  Pclass  SibSp  Parch  Survived  Family_Size
# 0    22.0       3      1      0         0            2
# 1    38.0       1      1      0         1            2
# 2    26.0       3      0      0         1            1
# 3    35.0       1      1      0         1            2
# 4    35.0       3      0      0         0            1
# ..    ...     ...    ...    ...       ...          ...
# 885  39.0       3      0      5         0            6
# 886  27.0       2      0      0         0            1
# 887  19.0       1      0      0         1            1
# 889  26.0       1      0      0         1            1
# 890  32.0       3      0      0         0            1
#
# [714 rows x 6 columns]

# %%
def func(temp):
    if(temp==1):
        return 0
    elif(temp>1 and temp<=4):
        return 1
    else:
        return 2

# %%
df['Family_Type']=df['Family_Size'].apply(func)

# %%
df
# Out:
#       Age  Pclass  SibSp  Parch  Survived  Family_Size  Family_Type
# 0    22.0       3      1      0         0            2            1
# 1    38.0       1      1      0         1            2            1
# 2    26.0       3      0      0         1            1            0
# 3    35.0       1      1      0         1            2            1
# 4    35.0       3      0      0         0            1            0
# ..    ...     ...    ...    ...       ...          ...          ...
# 885  39.0       3      0      5         0            6            2
# 886  27.0       2      0      0         0            1            0
# 887  19.0       1      0      0         1            1            0
# 889  26.0       1      0      0         1            1            0
# 890  32.0       3      0      0         0            1            0
#
# [714 rows x 7 columns]

# %%
df.drop(['SibSp',"Parch",'Family_Size'],axis=1,inplace=True)

# %%
df
# Out:
#       Age  Pclass  Survived  Family_Type
# 0    22.0       3         0            1
# 1    38.0       1         1            1
# 2    26.0       3         1            0
# 3    35.0       1         1            1
# 4    35.0       3         0            0
# ..    ...     ...       ...          ...
# 885  39.0       3         0            2
# 886  27.0       2         0            0
# 887  19.0       1         1            0
# 889  26.0       1         1            0
# 890  32.0       3         0            0
#
# [714 rows x 4 columns]

# %%
np.mean(cross_val_score(LogisticRegression(),df.iloc[:,[0,1,3]],df.iloc[:,2],scoring='accuracy',cv=20))
# Out:
# 0.7003174603174602

# %% [markdown]
# Feature Splitting

# %%
df1=pd.read_csv('titanic.csv')

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#expand gives us whole index 1 values rather than only first row
df1['Titled']=df1['Name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]

# %%
df1
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
